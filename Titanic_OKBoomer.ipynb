# %% [markdown]
# <a href="https://colab.research.google.com/github/haramrit09k/100-days-of-code/blob/master/Titanic_OKBoomer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 151          152         1       1  ...  66.6000    C2         S
# 152          153         0       3  ...   8.0500   NaN         S
# 153          154         0       3  ...  14.5000   NaN         S
# 154          155         0       3  ...   7.3125   NaN         S
# 155          156         0       1  ...  61.3792   NaN         C
#
# [156 rows x 12 columns]

# %%
generation = []
for age in data["Age"]:
  if age < 20:
    generation.append("Kid")
  elif age in range(21,40):
    generation.append("Millenial")
  elif age >=40:
    generation.append("OK Boomer")
  else:
    generation.append(np.nan)
generation
# Out:
# ['Millenial',
#  'Millenial',
#  'Millenial',
#  'Millenial',
#  'Millenial',
#  nan,
#  'OK Boomer',
#  'Kid',
#  'Millenial',
#  'Kid',
#  'Kid',
#  'OK Boomer',
#  nan,
#  'Millenial',
#  'Kid',
#  'OK Boomer',
#  'Kid',
#  nan,
#  'Millenial',
#  nan,
#  'Millenial',
#  'Millenial',
#  'Kid',
#  'Millenial',
#  'Kid',
#  'Millenial',
#  nan,
#  'Kid',
#  nan,
#  nan,
#  'OK Boomer',
#  nan,
#  nan,
#  'OK Boomer',
#  'Millenial',
#  'OK Boomer',
#  nan,
#  'Millenial',
#  'Kid',
#  'Kid',
#  'OK Boomer',
#  'Millenial',
#  nan,
#  'Kid',
#  'Kid',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Kid',
#  'Kid',
#  'Millenial',
#  'OK Boomer',
#  'Millenial',
#  'OK Boomer',
#  nan,
#  'Millenial',
#  nan,
#  'Kid',
#  'Kid',
#  'Millenial',
#  'Millenial',
#  'OK Boomer',
#  'Kid',
#  nan,
#  nan,
#  'Millenial',
#  'Kid',
#  'Kid',
#  'Millenial',
#  'Millenial',
#  'Kid',
#  'Millenial',
#  'Millenial',
#  'Millenial',
#  'Millenial',
#  nan,
#  nan,
#  'Kid',
#  'Millenial',
# ...

# %%
data["Generation"] = generation
data
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Generation
# 0              1         0       3  ...   NaN        S   Millenial
# 1              2         1       1  ...   C85        C   Millenial
# 2              3         1       3  ...   NaN        S   Millenial
# 3              4         1       1  ...  C123        S   Millenial
# 4              5         0       3  ...   NaN        S   Millenial
# ..           ...       ...     ...  ...   ...      ...         ...
# 151          152         1       1  ...    C2        S   Millenial
# 152          153         0       3  ...   NaN        S   OK Boomer
# 153          154         0       3  ...   NaN        S   OK Boomer
# 154          155         0       3  ...   NaN        S         NaN
# 155          156         0       1  ...   NaN        C   OK Boomer
#
# [156 rows x 13 columns]

# %%
data["Generation"].fillna("No Age", inplace = True)
data
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Generation
# 0              1         0       3  ...   NaN        S   Millenial
# 1              2         1       1  ...   C85        C   Millenial
# 2              3         1       3  ...   NaN        S   Millenial
# 3              4         1       1  ...  C123        S   Millenial
# 4              5         0       3  ...   NaN        S   Millenial
# ..           ...       ...     ...  ...   ...      ...         ...
# 151          152         1       1  ...    C2        S   Millenial
# 152          153         0       3  ...   NaN        S   OK Boomer
# 153          154         0       3  ...   NaN        S   OK Boomer
# 154          155         0       3  ...   NaN        S      No Age
# 155          156         0       1  ...   NaN        C   OK Boomer
#
# [156 rows x 13 columns]

# %%
data.groupby(data["Generation"]).count().plot.pie(y="Age")
